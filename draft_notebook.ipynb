# %%
# !pip install pymupdf
# !pip install --upgrade transformers datasets accelerate bitsandbytes peft trl sentence-transformers
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 60.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.26.7
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Collecting transformers
#   Downloading transformers-5.0.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.4.2)
# Collecting datasets
#   Downloading datasets-4.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Collecting accelerate
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.1)
# Collecting peft
#   Downloading peft-0.18.1-py3-none-any.whl.metadata (14 kB)
# Collecting trl
#   Downloading trl-0.27.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.1)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.3)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers)
#   Downloading huggingface_hub-1.3.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0rc2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from accelerate) (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.2.1rc0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->accelerate) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->transformers) (8.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Downloading transformers-5.0.0-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 70.3 MB/s eta 0:00:00:00:01:01
# Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 38.4 MB/s eta 0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 26.9 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 33.8 MB/s eta 0:00:00:00:0100:01
# Downloading peft-0.18.1-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 35.3 MB/s eta 0:00:00
# Downloading trl-0.27.1-py3-none-any.whl (532 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 34.5 MB/s eta 0:00:00
# Downloading sentence_transformers-5.2.2-py3-none-any.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 32.8 MB/s eta 0:00:00
# Downloading huggingface_hub-1.3.5-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 34.7 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, datasets, bitsandbytes, accelerate, transformers, trl, sentence-transformers, peft
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.4.2
#     Uninstalling datasets-4.4.2:
#       Successfully uninstalled datasets-4.4.2
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.11.0
#     Uninstalling accelerate-1.11.0:
#       Successfully uninstalled accelerate-1.11.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Uninstalling transformers-4.57.1:
#       Successfully uninstalled transformers-4.57.1
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.1.1
#     Uninstalling sentence-transformers-5.1.1:
#       Successfully uninstalled sentence-transformers-5.1.1
#   Attempting uninstall: peft
#     Found existing installation: peft 0.17.1
#     Uninstalling peft-0.17.1:
#       Successfully uninstalled peft-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# Successfully installed accelerate-1.12.0 bitsandbytes-0.49.1 datasets-4.5.0 huggingface-hub-1.3.5 peft-0.18.1 sentence-transformers-5.2.2 transformers-5.0.0 trl-0.27.1
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-r6pz_kx0/unsloth_c687caad99b94e90a6d6dbb19a29f944
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-r6pz_kx0/unsloth_c687caad99b94e90a6d6dbb19a29f944
#   Resolved https://github.com/unslothai/unsloth.git to commit 07a7ff47b1b2b37c088b8e0d7ed7bf8710d9aa22
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting unsloth_zoo>=2026.1.4 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading unsloth_zoo-2026.1.4-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (26.0rc2)
# Collecting tyro (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading tyro-1.0.5-py3-none-any.whl.metadata (12 kB)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.8 MB/s eta 0:00:00
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.0.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.29.5)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.5)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.9)
# Requirement already satisfied: bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.49.1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.2.2)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.6.0)
# Collecting multiprocess<0.70.17 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.9.0,>=2023.1.0 (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.2.1rc0)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.15.0)
# Collecting huggingface_hub>=0.34.0 (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,<=4.57.6,>=4.51.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.6.2)
# Collecting torchao>=0.13.0 (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading torchao-0.15.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.12.0)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.18.1)
# Collecting cut_cross_entropy (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.3.0)
# Collecting msgspec (from unsloth_zoo>=2026.1.4->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.15.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.4.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.13.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.11.1.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub>=0.34.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (8.3.1)
# Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 14.2 MB/s eta 0:00:0000:01
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 98.8 MB/s eta 0:00:00:00:010:01
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 37.7 MB/s eta 0:00:00
# Downloading unsloth_zoo-2026.1.4-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 kB 23.7 MB/s eta 0:00:00
# Downloading tyro-1.0.5-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 kB 12.4 MB/s eta 0:00:00
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 14.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 10.6 MB/s eta 0:00:00
# Downloading torchao-0.15.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 53.6 MB/s eta 0:00:0000:0100:01
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 20.4 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading msgspec-0.20.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 16.4 MB/s eta 0:00:00
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2026.1.4-py3-none-any.whl size=412718 sha256=d269bda64765714ba5a328fe61e1fae0fcb1c7e55072b8e37524263fc5118d97
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8wsx5qlh/wheels/60/3e/1f/e576c07051d90cf64b6a41434d87ccf4db33fafd5343bf5de0
# Successfully built unsloth
# Installing collected packages: torchao, unsloth, multiprocess, msgspec, fsspec, tyro, huggingface_hub, transformers, datasets, cut_cross_entropy, trl, unsloth_zoo
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.18
#     Uninstalling multiprocess-0.70.18:
#       Successfully uninstalled multiprocess-0.70.18
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.10.0
#     Uninstalling fsspec-2025.10.0:
#       Successfully uninstalled fsspec-2025.10.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.3.5
#     Uninstalling huggingface_hub-1.3.5:
#       Successfully uninstalled huggingface_hub-1.3.5
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.5.0
#     Uninstalling datasets-4.5.0:
#       Successfully uninstalled datasets-4.5.0
#   Attempting uninstall: trl
#     Found existing installation: trl 0.27.1
#     Uninstalling trl-0.27.1:
#       Successfully uninstalled trl-0.27.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.9.0 which is incompatible.
# Successfully installed cut_cross_entropy-25.1.1 datasets-4.3.0 fsspec-2025.9.0 huggingface_hub-0.36.0 msgspec-0.20.0 multiprocess-0.70.16 torchao-0.15.0 transformers-4.57.6 trl-0.24.0 tyro-1.0.5 unsloth-2026.1.4 unsloth_zoo-2026.1.4

# %%
import fitz
import os
pdf_folder = '/kaggle/input/forensic/'
pdf_files = [os.path.join(pdf_folder, f) for f in os.listdir(pdf_folder) if f.lower().endswith('.pdf')]
def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text("text") + "\n\n"
    doc.close()
    return full_text.strip()
all_text = ""
for pdf in pdf_files:
    text = extract_text_from_pdf(pdf)
    all_text += f"\n\n-- Document: {os.path.basename(pdf)} -- \n\n" + text

with open("corpus_forensic.txt", "w", encoding="utf-8") as f:
    f.write(all_text)

print(f"Texte total extrait {len(all_text)}")
# Out:
# Texte total extrait 1151740

# %%
def chunk_text(text, max_length=1200):
    chunks = []
    current = ""
    for line in text.split("\n"):
        if len(current) + len(line) > max_length:
            chunks.append(current.strip())
            current = line
        else:
            current += " " + line
    if current:
        chunks.append(current.strip())
    return chunks

chunks = chunk_text(all_text)
print(f"{len(chunks)} chunks créés")
# Out:
# 981 chunks créés

# %%
def extract_json_from_response(response):
    start = response.find('[')
    if start == -1:
        print("Aucun tableau JSON trouvé")
        return []
    
    candidate = response[start:]
    
    brace_count = 0
    fixed = ""
    for char in candidate:
        fixed += char
        if char == '{':
            brace_count += 1
        elif char == '}':
            brace_count -= 1
            if brace_count == 0 and fixed.endswith('}'):
                if not fixed.strip().endswith(']'):
                    fixed = fixed.rstrip() + ','
    
    if not fixed.strip().endswith(']'):
        fixed = fixed.rstrip(',') + ']'
    
    fixed = re.sub(r',\s*]', ']', fixed)
    fixed = re.sub(r'\}\s*,?\s*$', '}', fixed)
    
    try:
        qa_list = json.loads(fixed)
        valid_qa = [item for item in qa_list if isinstance(item, dict) and "question" in item and "answer" in item and item["answer"].strip()]
        if valid_qa:
            return valid_qa
        else:
            print("Aucun objet valide après filtre")
            return []
    except json.JSONDecodeError as e:
        print(f"Erreur même après réparation : {e}")
        print("JSON tenté :", fixed[:500])
        return []

# %%
from unsloth import FastLanguageModel
import json
import re
from tqdm.auto import tqdm
import torch

# === Chargement du modèle (déjà fait dans ton code) ===
model_name = "unsloth/gemma-2-9b-it-bnb-4bit"  # ou autre
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name,
    max_seq_length=4096,
    dtype=None,
    load_in_4bit=True,
)
FastLanguageModel.for_inference(model)

# === Fonction de génération (améliorée) ===
def generate_qa(chunk):
    prompt = f"""Tu es un générateur QA pour digital forensics. Pour ce chunk de texte UNIQUEMENT :

- Génère EXACTEMENT 6 à 8 questions-réponses différentes et pointues.
- Questions variées : outils, commandes, formats de fichiers, artefacts par OS, étapes d'analyse, timelines, registres, prefetch, etc.
- INTERDICTION ABSOLUE : ne répète JAMAIS une question ou un thème similaire à ceux déjà générés auparavant.
- Ne pose PAS de questions sur Volatility pslist, mémoire vive ou listes de processus sauf si le chunk en parle explicitement de façon nouvelle.
- Réponses : courtes, extraites mot pour mot ou presque du texte.
- Réponds UNIQUEMENT avec le JSON valide. Pas de texte avant/après. Pas de markdown.

Texte du chunk :
{chunk[:3000]}

Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
Tu DOIS générer exactement 6 paires complètes. Chaque paire doit être un objet JSON complet avec "question" et "answer" valides. Ne laisse JAMAIS un objet ouvert ou une virgule en trop. Si le chunk est court, génère moins mais toujours complet."""

    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=1200,             # Monte beaucoup plus haut (tes paires sont longues)
            temperature=0.5,                 # Équilibre : pas trop bas
            top_p=0.9,
            do_sample=True,                  # Nécessaire pour éviter coupures déterministes
            repetition_penalty=1.3,          # Pénalise fortement les répétitions / boucles
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id
        )
    
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response  # on retourne la raw response, parsing après

# === Fonction de parsing robuste (améliorée) ===

def extract_json_from_response(response):
    # Étape 1 : Trouver le début et la fin potentielle du tableau
    start = response.find('[')
    if start == -1:
        print("Aucun [ trouvé → pas de JSON")
        return []
    
    candidate = response[start:]
    
    # Étape 2 : Nettoyage agressif
    # Supprimer virgules multiples ,, ou trailing ,
    candidate = re.sub(r',,+', ',', candidate)
    candidate = re.sub(r',\s*([}\]])', r'\1', candidate)  # virgule avant } ou ]
    
    # Étape 3 : Équilibrer les accolades et crochets
    brace_open = candidate.count('{')
    brace_close = candidate.count('}')
    bracket_open = candidate.count('[')
    bracket_close = candidate.count(']')
    
    if brace_open > brace_close:
        candidate += '}' * (brace_open - brace_close)
    if bracket_open > bracket_close:
        candidate += ']' * (bracket_open - bracket_close)
    
    # Étape 4 : Couper au premier ] valide (éviter texte parasite après)
    end_match = re.search(r'\].*?$', candidate, re.DOTALL)
    if end_match:
        candidate = candidate[:end_match.end()]
    
    # Étape 5 : Tentative de parse
    try:
        data = json.loads(candidate)
        if isinstance(data, list):
            # Garder seulement les paires complètes
            valid_pairs = []
            for item in data:
                if (isinstance(item, dict) and 
                    "question" in item and isinstance(item["question"], str) and 
                    "answer" in item and isinstance(item["answer"], str) and 
                    item["answer"].strip()):  # answer non vide
                    valid_pairs.append(item)
            if valid_pairs:
                return valid_pairs
            else:
                print("Aucune paire valide après filtre")
        else:
            print("Pas une liste")
    except json.JSONDecodeError as e:
        print(f"Erreur JSON finale : {e}")
        print("JSON après réparation (premiers 600 chars) :", candidate[:600])
    
    # Dernier recours : extraction manuelle basique des paires
    manual_pairs = []
    pattern = r'\{\s*"question"\s*:\s*"([^"]*)"\s*,\s*"answer"\s*:\s*"([^"]*)"\s*\}'
    for match in re.finditer(pattern, response):
        q, a = match.groups()
        if a.strip():
            manual_pairs.append({"question": q, "answer": a})
    
    if manual_pairs:
        print(f"Récupéré {len(manual_pairs)} paires via regex fallback")
        return manual_pairs
    
    return []

def fallback_regex_extraction(response):
    pairs = []
    # Pattern plus souple : accepte guillemets simples ou doubles, espaces variables
    pattern = r'{\s*["\']?question["\']?\s*:\s*["\']([^"\']*)["\']\s*,\s*["\']?answer["\']?\s*:\s*["\']([^"\']*)["\']\s*}'
    for match in re.finditer(pattern, response, re.IGNORECASE | re.DOTALL):
        q, a = match.groups()
        q = q.strip().replace('\\', '')  # enlever escapes inutiles
        a = a.strip().replace('\\', '')
        if q and a:
            pairs.append({"question": q, "answer": a})
    return pairs

# === Boucle de génération CORRECTE ===
all_qa_pairs = []

for chunk in tqdm(chunks, desc="Génération Q/R"):
    if not chunk.strip():  # skip chunks vides
        continue
        
    raw_response = generate_qa(chunk)
    qa_list = extract_json_from_response(raw_response)
    
    if qa_list:
        all_qa_pairs.extend(qa_list)
    else:
        print(f"Échec parsing sur un chunk → ignoré")

# === Sauvegarde ===
with open("forensic_qa_dataset.json", "w", encoding="utf-8") as f:
    json.dump(all_qa_pairs, f, ensure_ascii=False, indent=2)

print(f"Total Q/R générées et parsées : {len(all_qa_pairs)}")
# Out:
# ==((====))==  Unsloth 2026.1.4: Fast Gemma2 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Génération Q/R:   0%|          | 0/981 [00:00<?, ?it/s]
# Erreur JSON finale : Expecting ':' delimiter: line 1 column 695 (char 694)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les versions des systèmes d'exploitation utilisés dans ces tests ?", "answer": "FreeBSD 4.4"}, {"question": "Quels types de partitions ont été représentés lors des tests ?", "answer": "FAT16, FAT32, NTFS ou Linux EXT2"}, {"question": "Où se situent les laboratoires où ces tests ont eu lieu ?", "answer": "Computer Forensics Tool Testing Lab at the National Institute of Standards and Technology"}, {"question": "Quel était l'objectif principal de ce document ?", "answer": "Provide enough information about the testing process"}, {"question": "Qui devrait lire ce documen
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 380 (char 379)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont des exemples de marques déposées mentionnées dans le document ?", "answer": "\"Power Quest Corporation\", \"Red Hat\", \"Linus Torvalds\" , \"Borland International\","}, {"question": "Quel logiciel peut manipuler les partitions ?", "answer": "Partition Magic®"}, {"question": "Quelle organisation édite FreeBSD ? ", "answer": "Non spécifié"} ,"question": "Quand date la version présentée ici ?" , "answer":" May 6, 2004"}, {"question": "Lequel des produits suivants n'est pas recommandé ni endorsed ?" , "answer": "Aucun produit spécifique"}}]
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Expecting ':' delimiter: line 1 column 289 (char 288)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les types de scripts test utilisés ?", "answer": "DOS Batch Files csh Scripts"}, {"question": "Quel système d'exploitation fait l'objet des tests ? ", "answer": " Windows 98 FreeBSD"}, {"question": "Quelle est la date du document ?", "answer": " May 6, 2","}, {"question": "Combien y a-t-il de sections dans cette liste ?" , "answer":" 6"}],"
#
#
#
# Récupéré 3 paires via regex fallback
# Aucune paire valide après filtre
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Extra data: line 1 column 569 (char 568)
# JSON après réparation (premiers 600 chars) : [{"question": "Quel organisme contribue au projet CFTT ?", "answer": "Le National Institute of Standards and Technology (NIST)."}, {"question": "Où sont publiées les spécifications et méthodes de tests?", "answer": "Sur le site web NIST: http://www.cftt.nist.gov/."}, {"question": "Quelle version de FreeBSD est mentionnée dans ce document ?", "answer": "Version 4.4"}, {"question": "Quels types de tests font partie de l’approche CFTT ?" , "answer":"Conformance testing and quality testing"}, {"question": " Quel outil est testé dans ce document ? ", "answer": "dd"}],"
#
#
#
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 599 (char 598)
# JSON après réparation (premiers 600 chars) : [{"question":"Quel type de disques durs sont utilisés dans ces tests ?","answer":"hard disks"}, {"question":"Quels types d'interfaces matérielles sont mentionnés concernant les disques durs? ","answer":"IDE or SCSI"}, {"question":"Quelles ressources supplémentaires seraient nécessaires pour reproduire les résultats des tests ?" ,"answer": "the dd test report, Disk Imaging Tool Specification, Version 3.1.6, the FS-TST 1.0 software plus revised error simulation software."}, {"question":"Lequel des systèmes d'exploitation suivants n'est pas spécifié comme requis pour comprendre ce document ?", an
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [DISKWIPE], comparison of a source with a destination [DISKCMP, PARTCMP,
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
# Tu DOIS générer exactement 6 paires complètes. Chaque paire doit être un objet JSON complet avec "question" et "answer" valides. Ne laisse JAMAIS un objet ouvert ou une virgule en trop. Si le chunk est court, génère moins mais toujours complet.
#
#
# {"question": "What is the purpose of comparing SHA-1 hashes?", "answer": "to verify if data has been altered
# Récupéré 7 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [DISKHASH and SECHASH]. All  programs were written in ANSI C and compiled with the Borland C++ compiler version  4.5. BADDISK and BADX13 were written in assembler language and compiled with  Borland Turbo Assembler version 5.0. The csh scripts were executed using the version of  csh provided with FreeBSD 4.4.      3 Media Setup  The test cases required several media components to be created before the test cases  could be executed. The following items were created.    1. Source hard disk drives for the test cases.    FreeBSD Test Environment  3  May 6, 2004  2. A media hard drive with FreeBSD,
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 743 (char 742)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels types de systèmes de fichiers sont inclus dans la première configuration ?","answer":"FAT16, Linux EXT2, partitions cachées et partitions supprimées"}, {"question": "Quelle taille était le disque dur utilisé pour la deuxième configuration ?", "answer":"N'est pas spécifié."}, {"question": "Quel outil a été utilisé pour créer toutes les partitions?", "answer":"Partition Magic Pro 6.0"}, {"question": "Quelles étaient les tailles des partitions FAT16 sous Windows ME?", "answer":"600 MB pour le lecteur C: , 70 MB pour le lecteur D:, 2000 MB pour une partition supprimée et 90 MB
# Récupéré 5 paires via regex fallback
# Aucun [ trouvé → pas de JSON
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Invalid \uXXXX escape: line 1 column 616 (char 615)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels types de systèmes de fichiers sont crées dans l'exemple ?", "answer": "NTFS, FAT32"}, {"question": "Comment la partition 'GONE2' est-elle supprimée ?", "answer": "Select Partition \"GONE2\" Delete \"GONE2\""}, {"question": "Quelle commande permet de masquer des partitions spécifiques ? ", "answer": " Hide"}, {"question": "Quel script est utilisé pour créer des fichiers supprimés ?" , "answer": " UDT-SET.BAT"}, {"question": "Quelles actions sont effectuées lors de la création du répertoire \\udt ?" , "answer": " mkdir %1:\\udt   "}, {"question": "Que fait la ligne `Copy A:
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 666 (char 665)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les noms des programmes copiés sur la clé USB ?", "answer": "EN.EXE, BADX13.COM Version 3.2 et BADDISK.COM Version 3.2"}, {"question": "Quel était l'objectif de modifier le fichier io.sys ?", "answer": "Pour supprimer toute référence au lecteur C:"}, {"question": "Où étaient stockés les scripts, images et journaux ? ", "answer": "/x répertoire"}, {"question": "Quelle commande permettait de faire tourner DD?", "answer":"Il n'est pas mentionné dans le text." }, {"question": "Comment s'appelait l'environnement d'exécution fourni par le disque dur bootable sous Windows 98
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 228 (char 227)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les pilotes chargés dans la configuration système ?", "answer": "ASPI SCSI , CDROM"}, {"question": "Quelle commande formaterait une disquette vierge sous FreeBSD?", "answer":" FORMAT A:/S"} ,"question": "Quel fichier contient des informations concernant l'ordre alphabétique des lettres de disque disponibles ?","answer": "CONFIG.SYS"}, {"question": "Quelles lignes configurent les paramètres de base tels que files, buffers, dos et stacks ? ","answer": "files=30 buffers=10 dos=high,umb stacks=9,256"}, {"question": "Comment configure-t-on le dernier numéro de lettre de le
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid \escape: line 1 column 525 (char 524)
# JSON après réparation (premiers 600 chars) : [{"question": "What is the purpose of START-IT.BAT?", "answer": "To start a test case"}, {"question": "Which parameters does START-IT.BAT take?", "answer": "hostname, operator, source, destination, boot media or partition type, size"}, {"question": "How many arguments are required for DST.BAT execution?", "answer": "One: hostname"}, {"question": "What command executes files in partitions according to their names?", "answer":"A:\\s\\xdst-pt %ThisCase% %%1 %Op% %Dst%" }, {"question": "What information can be found in `A:\CASE.TXT`?", "answer": "Script version and system info"}, {"question": "Whe
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 241 (char 240)
# JSON après réparation (premiers 600 chars) : [{"question":"Quel outil analyse la table des partitions ?","answer":"Z:\\ss\\partab"},{"question":"Quelle commande compare deux disques? ","answer":"Z:\\ss\\diskcmp"}, {"question":"Comment nomme l'outil `partab` ses fichiers journaux ?" , answer": 'A:\\PT81LOG.TXT'"}]
#
#
#
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Invalid \escape: line 1 column 199 (char 198)
# JSON après réparation (premiers 600 chars) : [{"question":"Quel outil était utilisé pour monter l'unité disquette ?", "answer":"\/x/mount-fd"}, {"question": "Comment étaient nommés les fichiers journaux copiés ?", "answer":"\/.*/logs/\/*_/copy\_log\.txt"}, {"question": "Quelle taille de bloc utilisait la commande 'dd_copy' ?" , "answer":"Un secteur (512 octets)"}]
#
#
#
# ```json
# [{"question":"Dans quel répertoire sont stockés les fichiers journaux des tests ?", "answer":"\\.*/logs/\"*_\""}, {"question":"Que faisait le script \"dd_image\" ?", "answer":"Créer un fichier image."}, {"question":"Lequel des deux scripts copiait directement un disq
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 609 (char 608)
# JSON après réparation (premiers 600 chars) : [{"question": "What is the purpose of line 14?", "answer": "created an image of a source on the media drive"}, {"question": "Where are the logs stored?", "answer": "/x/logs/$3"}, {"question": "Which commands were used for backing up and restoring data?", "answer": "dk-backup and dk-restore"}, {"question": "After what action does the script copy any log files to the floppy drive?", "answer":"after the restore was finished"}, {"question": "How big are the blocks read/written during disk imaging?", "answer": "bs=5"} , {"question": "When did the process start according to lines 10 & 20?","answer":
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [ABR]$3.TXT /x/fd      Figure 4-11 Script to Acquire (dk-backup)  1. #!/bin/csh -f  2. if ($#argv != 2) then  3. echo "Usage: $0 src_dev test_case  4. exit (1)  5. endif    FreeBSD Test Environment  12  May 6, 2004  6. #set echo  7. set src = $1  8. set dst_dir = /x/img/$2  9. set log_file = /x/logs/$2/B$2.TXT  10. echo "dk-backup $argv" >$log_file  11. date >> $log_file  12. echo "dk-backup $argv"  13. #rm -r -f $dst_dir  14. mkdir $dst_dir  15. @ total = 1  16. @ max = 1000000  17. @ n = $max  18. @ skip = 0  19. @ pass = 100  20. #@ nf = ($total / $max) + 1  21. #echo "$nf image files requi
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Extra data: line 5 column 1 (char 327)
# JSON après réparation (premiers 600 chars) : [{"question":"Quel outil est utilisé dans cet exemple ?","answer":"dk-restore"}, {"question": "Où sont enregistrées l'heure de début et la fin des opérations ? ","answer":"Dans le fichier $log_file"} ,{"question":"Quelle commande affiche le contenu du script dk-restore?" ,"answer":"echo \"dk-restore $argv\" > $log_file"}]
#
#
#
# ```json
# ["{'question': 'Quelles variables stockent le chemin cible et le nom du cas de test ?', 'answer': '$dst et $2'}, {'question': 'Comment s\'appelle le fichier journal ?', 'answer': '/x/logs/$2/R$2.TXT'}, {'question': 'Qu\'est-ce que \'dd\', ici ?' ,'answer':'Un utili
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 252 (char 251)
# JSON après réparation (premiers 600 chars) : [{"question":"Quel outil était utilisé pour l'imagerie physique ?","answer":"dd_image"},{"question": "Quelle commande a été exécutée pour monter la partition? ","answer":"/x/mount-fd"}, {"question": "Qu'est-ce qui se passait dans les cas de copie ?", answer:"Le script /x/dd_copy était exécuté."}, {"question": "Comment étaient traités les secteurs excédentaires?", "answer":"Ils ont été hachés avec SECHASH.EXE (si requis)"} ,{"question": "Quand s'exécutait le script CMP.BAT", "answer":"Dans les cas physiques de disque dur."}]
#
#
#
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 392 (char 391)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les principes généraux abordés dans cet extrait ?", "answer": "General principles"}, {"question": "Quelles classes de processus d'investigation numérique existent ?", "answer": "Classes of digital investigation processes"}, {"question": "Où se trouvent des informations concernant la préparation aux investigations numériques ?" , "answer": "Readiness processes"} ]}
# Récupéré 3 paires via regex fallback
# Aucune paire valide après filtre
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Extra data: line 1 column 680 (char 679)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les quatre premières phases décrites dans la section ?", "answer": "Incident detection process, First response process, Planning process, Preparation process"}, {"question": "À quelle étape se trouve l’incident détection ?", "answer": "Section 8.2"},  {"question": "Quel type de document contient ces informations ?", "answer":"Digital forensic investigation report"}, {"question": "Que fait on au cours de la phase 'Preparation process'" , "answer": "Not specified in the provided text."}, {"question": "Quelle information essentielle manque concernant chaque phase ?" ,"
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 682 (char 681)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont des mesures qui peuvent affecter l'investigation?", "answer": "Security mechanisms like encryption"}, {"question": "Pourquoi faut-il considérer ces mécanismes ?", "answer": "prior to and during the conduct of an investigation."}, {"question": "Quel type de guidances offre cet ensemble standard ? ", "answer": "guidance on how to provide assurance that methods and processes meet the requirements of the investigation"} , {"question": "Quels aspects importants aborde la conception et mise en œuvre des méthodes utilisées dans une enquête selon cette norme internationale?
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 317 (char 316)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles actions peuvent résulter des violations de sécurité inévitables ?", "answer": "Actions"}, {"question": "Quels sont les trois aspects clés que l'information technologique vise à maximiser dans la gestion probatoire?", "answer": "'evidential availability', 'accessibility','cost efficiency'}, {"question": "Quelle figure illustre typiquement les activités entourant un incident et son enquête ?", "answer": "Figure 1"}, {"question":"Que représentent les nombres mentionnés dans le schéma ?","answer": "International Standards"}, {"question": "Où montre-t-on où chaque standard in
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [SOURCE: ISO/IEC 27037:2012, 3.1] 3.2 activity set of cohesive tasks of a process [SOURCE: ISO/IEC 12207:2008, 4.3] 3.3 analysis process of evaluating potential digital evidence in order to assess its relevance to the investigation
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
# Tu DOIS générer exactement 6 paires complètes. Chaque paire doit être un objet JSON complet avec "question" et "answer" valides. Ne laisse JAMAIS un objet ouvert ou une virgule en trop. Si le chun
# Récupéré 1 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [SOURCE: ISO/IEC 27042:—, 3.1] INTERNATIONAL STANDAR ISO/IEC 27043:2015(E) © ISO/IEC 2015 – All rights reserve 1   ﻿ ISO/IEC 27043:2015(E) 3.4 collection process of gathering the physical items that contain potential digital evidence [SOURCE: ISO/IEC 27037:2012, 3.3] 3.5 digital evidence information or data, stored or transmitted in binary form, that may be relied on as evidence [SOURCE: ISO/IEC 27037:2012, 3.5] 3.6 digital investigation use of scientifically derived and proven methods towards the identification, collection, transportation,  storage, analysis, interpretation, presentation,
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [SOURCE: ISO/IEC 27037:2012, 3.12] 3.8 incident single or a series of unwanted or unexpected information security breaches or events, whether of  criminal nature or not, that have a significant probability of compromising business operations or  threatening information security 3.9 interpretation synthesis of an explanation, within agreed limits, for the factual information about evidence resulting  from the set of examinations and analysis making up the investigation [SOURCE: ISO/IEC 27042:—, 3.9] 3.10 investigation application of examinations, analysis, and interpretation to aid understandin
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [SOURCE: ISO/IEC  27042:—, 3.15, modified — Definition adapted to refer to the abstract process  “examination and analysis” rather than analysis only; note 1 and note 2 to entry not included.] 3.13 preservation process to maintain and safeguard the integrity and/or original condition of the potential digital  evidence and digital evidence [SOURCE: ISO/IEC 27037:2012, 3.15, modified — Added “and digital evidence”.] 3.14 process set of activities that have a common goal and last for a limited period of time Note 1 to entry: Also see ISO/IEC 27000 and ISO 9000 for similar definitions of a process
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [SOURCE: ISO/IEC 27004:2009, 3.17] 3.17 verification confirmation, through the provision of objective evidence, that specified requirements have been fulfilled Note 1 to entry: Verification only provides assurance that a product conforms to its specification. [SOURCE: ISO/IEC 27041:—, 3.20] 3.18 volatile data caused by data that is especially prone to change and can be easily modified Note 1 to entry: Change can be switching off the power or passing through a magnetic field. Volatile data also includes  data that changes as the system state changes. Examples include data stored in RAM and dyna
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 5 (char 4)
# JSON après réparation (premiers 600 chars) : [2] To help assure admissibility of expert opinion, the following factors should be  considered (as applicable in the particular jurisdiction): —	 whether the theories and techniques employed by the scientific expert have been tested;
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
# Tu DOIS générer exactement 6 paires complètes. Chaque paire doit être un objet JSON complet avec "question" et "answer" valides. Ne laisse JAMAIS un objet ouvert ou une virgule en trop. Si le c
# Récupéré 1 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 137 (char 136)
# JSON après réparation (premiers 600 chars) : [{"question":"Quelles sont les conditions générales requises pour l’admissibilité des preuves dans plusieurs juridictions ?","answer":""relevance\uFFFD"}] , [{"question":"Quels aspects doivent absolument faire l'objet d'une expertise selon la norme ISO/IEC 27042? ","answer":"whether they have been subjected to peer review and publication"}, {"question":"Selon la norme ISO/IEC 27042, quelle information concernant une technique devrait être rapportée si elle est connue?","answer":"if an error rate for the technique is known it should be reported"}, {"question":"La norme ISO/IEC 27042 mentionne-t
# Récupéré 2 paires via regex fallback
# Aucune paire valide après filtre
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 323 (char 322)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les catégories principales des processus d'investigation numérique ?", "answer": "— Readiness processes"}, {"question": "Quels types de stratégies définissent les processus de préparation?", "answer": "stratégies qui peuvent être employées à assurer que les systèmes sont en place"} ,"question": "A quoi servent les processus de préparation dans l'enquête numérique?","answer":"assurer que les systèmes sont en place, et que la formation du personnel impliqué dans le processus d’enquête soit adéquate."}]
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 835 (char 834)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les groupes inclus dans la planification des activités ?", "answer": "Le groupe 'implementing system architecture', le groupe 'pre-incident gathering, storage, and handling of data representing potential digital evidence'"}, {"question": "Comment l’évaluation se relie aux processus d’implémentation ?", "answer": "'The assessment processes group includes readiness processes...that are concerned with the assessment of the implementation success'" }, {"question": "Quel document illustre les liens entre les différents groupes de processus ?", "answer": "Figure 4"}, {"ques
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 749 (char 748)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les recommandations concernant l'évaluation des risques ?", "answer": "Il est recommandé que chaque scénario identifié soit accompagné d’une évaluation des risques."}, {"question": "Quel est l'objectif principal du processus de définition du scénario ?", "answer": "Examiner tous les scénarios probables où la preuve numérique pourrait être requise"}, {"question": "Qu'est-ce qui peut influencer les décisions relatives aux contrôles dans les processus ultérieurs ?", "answer": "L'évaluation des risques effectuée lors de certains menaces, vulnérabilités ou scénarios"}, {
# Récupéré 4 paires via regex fallback
# Aucune paire valide après filtre
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 498 (char 497)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels systèmes peuvent servir de système de surveillance dans l'infrastructure ?","answer":"intrusion prevention systems, intrusion detection systems, change tracking systems, log processing systems"}, {"question": "Quelle action faut-il définir lors de la planification du processus de détection des incidents ? ","answer":"actions à effectuer lorsqu’un incident est détecté"} ,{"question": "Que devrait inclure l’information transmise au reste du processus d’enquête numérique ?", answer:"informations préconnues concernant les entrées du système,"}, {"question": "Quelles information
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 832 (char 831)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels types d'événements peuvent déclencher l'incident?", "answer": "'changements dans un archivé log', 'intrusion détectée via système IDS"}, {"question": "Quel facteur influence la définition des incidents nécessitant une enquête numérique ?", "answer": "les politiques de l’organisation"}, {"question": "Comment se positionne le processus de détection d'incidents vis-à-vis des autres phases ?", "answer": "interface vers le reste du processus d'enquête numérique"} , {"question": "Pourquoi y a-t-il chevauchement entre préparation aux incidents et enquêtes numériques ?", "answer":
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid \escape: line 1 column 115 (char 114)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les deux principales actions recommandées dans la phase 'Evaluation des résultats de l\'implémentation'" , "answer":"décider sur les recommandations pour les changements"}, {"question": "Selon le document, qu'est-ce qui peut justifier que cette étape soit optionnelle ?", "answer":"il est possible que aucun changement n’est nécessaire"} ,"question": "Que fait cet analyseur au cours de la phase 'Évaluation de la préparation aux enquêtes numériques'", "answer":"compare groupement de processus "}
#
#
#
# ]
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 391 (char 390)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels types de systèmes sont mentionnés comme exemples de systèmes externes de détection des incidents ?", "answer": "intrusion detection systems, intrusion prevention systems, log-analysing systems"}, {"question": "Que faut-il faire selon la norme ISO/IEC 27043:2 l’avant même de commencer le processus de réponse aux incidents?", "answer": "Incident detection procedures"}],"
#
#
#
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 673 (char 672)
# JSON après réparation (premiers 600 chars) : [{"question":"Quelles sont les trois sous-processus clés dans la gestion des incidents numériques ?","answer":"incident detection, incident classification, and incident description"}, {"question": "Pourquoi l'incident detection n'est-elle pas considérée comme une activité préparatoire au lieu d'être le premier processus ?" , "answer": "digital investigation readiness activities should exist in a process separate to the rest of the digital investigation process."}, {"question": "Selon le document, quel type d'activité devrait être évité lors de la classification et de la description des inciden
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 864 (char 863)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels sont les facteurs qui influencent la variation des procédés dans l’enquête numérique ?","answer":"Le type de systèmes informatiques cibles, les données contenues dans ces systèmes, les circonstances de l’incident, sa classification et sa description."}, {"question": "Quelle étape précède toutes les autres phases de l'enquête numérique?", "answer": "La première réponse"}, {"question": "Comment s'appelle le standard utilisé pour développer les procédures utilisées lors d'une enquête numérique? ","answer": "ISO/IEC 27041"}, {"question": "Quelles ressources doivent être planifi
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 375 (char 374)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les trois priorités principales lors de la planification d'une enquête?", "answer": "minimiser les coûts de l'enquête , minimiser interférences avec et prévenir l’interruption des processus métier"}, {"question": "Quel aspect crucial détermine l'efficacité et le succès des autres phases ?", "answer": "le processus de planification"} ,"question": "Quels types d'éléments doivent être préparés pendant le processus de préparation ? ", "answer": "l'équipement matériel et logiciel, l'infrastructure, les ressources humaines "} ]}
#
#
#
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 391 (char 390)
# JSON après réparation (premiers 600 chars) : [{"question":"Quelles sont des bonnes pratiques recommandées concernant l'obtention d'images vérifiables ?","answer":"utiliser des fonctions hachage (voir ISO/IEC 10118- 2)"}, {"question": "Où trouver des conseils sur la gestion potentielle de preuves numériques? ","answer":"dans ISO/IEC 27037"} , {"question": "Quel type de régulation peut influencer l’acquisition de preuve numérique?", answer:"légale "}   ]
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 504 (char 503)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels sont les quatre processus clés impliqués dans l'interprétation des preuves numériques ?","answer":"digital evidence interpretation process, reporting process, presentation process, and investigation closure process."}, {"question": "Selon le document, quelle technique peut compléter la validation manuelle lors de l'analyse numérique? ","answer":"accredited automated techniques"},{"question": "Quel type de données représente le plus grand défi pour l'analyse numérique actuelle?",{ "answer":"volume, diversity and complexity"} },{"question": "Que faut-il définir lorsqu'on étab
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 256 (char 255)
# JSON après réparation (premiers 600 chars) : [{"question": "Quel document détaille la procédure d'interprétation des preuves numériques ?", "answer": "ISO/IEC 27"}, {"question": "Le rapport final issu de l'analyse numérique devrait idéalement prendre quel format ? ", "answer": "Imprimé sur papier"}],"
#
#
#
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 773 (char 772)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels types de personnes peuvent lire un rapport numérique ?", "answer":"judges, juries, the accused, lawyers, prosecutors, an organisation’s management team, shareholders, and employees"}, {"question": "Quelles sont les conséquences potentielles d'un mauvais rapport?", "answer":"wrong or misinterpreted reports."}, {"question":"Que faut-il faire pour s'assurer qu'aucune preuve importante n'est omise dans le rapport ?" , "answer":" diligence should be exercised to list all relevant digital evidence in the report"} , {"question":"Quel type de langage devrait utiliser un rapport ?",
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 804 (char 803)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les différents types de processus dans l'enquête numérique ?", "answer": "readiness, initialization, acquisitive, and investigative"}, {"question": "Qu'est-ce qu'un processus concurrentiel ?", "answer": "les principes qui devraient être appliqués tout au long du processus d’enquête numérique."}, {"question": "Donnez des exemples de processus parallèles.", "answer": "documentation, managing information flow, preserving chain of custody,"}, {"question": "Pourquoi la documentation est-elle considérée comme un processus parallèle ?" , "answer": "applicable à tous les proc
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 864 (char 863)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les raisons principales de la nécessité de documenter chaque étape des processus lors d’une enquête numérique ?", "answer": "Pour assurer la répétabilité et la reproductibilité, préserver la chaîne de garde et améliorer l'efficacité."}, {"question": "Quels types de documents doivent figurer dans la documentation du lieu de l'incident ?", "answer": "Écrits, croquis, photographies, vidéos et étiquettes potentielles de preuves numériques"}, {"question": "En quoi consiste la documentation du lieu de l'incident ?", "answer":"Il s'agit de documentations effectuée au site
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 113 (char 112)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels sont des exemples concrets où l'on peut revenir en arrière dans la procédure ?","answer":"a)	When, during the investigation closure process, it is noted that there is a need for additional digital evidence and that not all potential digital evidence were identified"}, {"question": "¿Qué se hace cuando durante el proceso de cierre de una investigación se observa que hay necesidad de evidencia digital adicional?", "answer": "one would go to the potential digital evidence identification process."}, {"question":"Quelles actions faut-il entreprendre lorsque certaines hypothèses
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 5 (char 4)
# JSON après réparation (premiers 600 chars) : [3] to [17] there exist clear  disparities among such digital investigation process models by the time of writing this International  Standard. Disparities include: different number of investigation processes included, different scope of  process models, different scope of the processes with the same names within different process models,  different hierarchy levels and even different concepts applied to the construction of the process model
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par
# Récupéré 1 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 5 (char 4)
# JSON après réparation (premiers 600 chars) : [3] to [17] in this field in order to harmonize the  digital investigation processes. Existing models are compared with the harmonized digital investigation  process model in Table A.1. The harmonized model is mapped to existing models in a bid to show how  it compared with existing models by the time of writing this International Standard. This also serves  as further motivation why the harmonized digital investigation process model should be standardized. The harmonized model is iterative and multi-tiered. Sub-processes of the model are not shown on the  comparison table for the sake of simp
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 936 (char 935)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les principaux avantages de l'utilisation du modèle harmonisé de processus d'enquête numérique ?", "answer": "Des multiples bénéfices"}, {"question": "Selon le document, quel élément devrait faire partie intégrante du processus d'enquête numérique ?" , "answer":"Incident detection and first response"} , {"question": "Le document mentionne-t-il des principes spécifiques applicables aux enquêtes numériques ?", "answer": "These processes provide the principles in digital investigations."}, {"question": "Comment la structure proposée dans le document améliore-t-elle l'eff
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 4 (char 3)
# JSON après réparation (premiers 600 chars) : [1][18] Reith et al.[3] DOJ[4] Carrier et al.[5] Mandia et al.[7] Beebe et al.[8] Cuardhuain[17] Cohen[9] Casey and  Rose[19] ACPO[20] Process 1. Incident  detection 1. Identification 1. Identification 2. Detection  and notification 2. Detection of  the incident 3. Initial  response 2. Incident  response 1. Awareness 2. First  response 3. Initial  response 2. Incident
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
# Tu DOIS générer exactement 6 paires complètes. Chaque pai
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 598 (char 597)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les différents types de préparation envisagée dans la phase 'Readiness'", "answer": "'Pre-incident preparation', 'Preparations for investigation'" }, {"question": "Que signifie l'étape 'Potential digital evidence identification'? ", "answer": "Identification des preuves numériques potentielles"}, {"question": "Quelles actions spécifiques doivent être prises lors de la collecte?", "answer": "'Gathering information and making observations'."}, {"question": "Quel est l'objectif principal de la préservation numérique ?", "answer": "Preserving digital crime scenes'}, {"que
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 4 (char 3)
# JSON après réparation (premiers 600 chars) : [1][18] Reith et al.[3] DOJ[4] Carrier et al.[5] Mandia et al.[7] Beebe et al.[8] Cuardhuain[17] Cohen[9] Casey and  Rose[19] ACPO[20] Process 10. Digital  evidence  interpreta- tion 4.5 Digital  crime scene  reconstruction 10. Hypothesis 7. Interpretation 8. Attribution 9. Reconstruc- tion 2. Form  hypothesis to  explain  observations, 3.Evaluate the  hypothesis, 4. Draw  conclusions and  communicate  findings. 5.3 The  examination  process 11. Reporting 8. Report 10. Reporting 5.4 The reporting  process 12. Presentation 6. Presentation 8. Presentation 8. Report 4.6 Presenta- tion  of digital
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 4 (char 3)
# JSON après réparation (premiers 600 chars) : [1][18] Reith et al.[3] DOJ[4] Carrier et al.[5] Mandia et al.[7] Beebe et al.[8] Cuardhuain[17] Cohen[9] Casey and  Rose[19] ACPO[20] Concurrent processes 1. Interaction  with physical  investigation 3. Physical  crime scene  investigation  group of phases As principle and  set of processes,  including preser- vance of physical  evidence and  interviews 2. Preserving  chain of  custody As principle As principle As principle As principle As principle As principle As principle As principle As principle As principle 3. Preserving  digital  evidence As principle As principle As principle As princ
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 6 (char 5)
# JSON après réparation (premiers 600 chars) : [1]	 Palmer  G. A Road Map for Digital Forensic Research”. Technical Report DTR-T001-01, DFRWS,  Report from the First Digital Forensic Research Workshop (DFRWS),  2001 [2]	 Daubert v. Merrell Dow Pharmaceuticals, Inc., 509 U.S. 579 ( 1993) [3]	 Reith  M., Carr  C., Gunsch  G. An examination of digital forensic models”, International Journal  of Digital Evidence,  2002 [4]	 The U.S. Department of Justice.  Electronic Crime Scene Investigation- A Guide for First  Responders,  2001 [5]	 Carrier  B., & Spafford  E.  Getting Physical with the Digital Investigation Process. International
#
# Génère UN
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Electronic version] [6]	 Carrier  B., & Spafford  E.  An Event-Based Digital Forensic Investigation Framework. Digit.  Invest.  2005,  2 (2) [7]	 Mandia  Kevin, Prosise  Chris, Pepe  Matt “Incident Response & Computer Forensics” (Second  Ed.),  McGraw-Hill/Osborne, Emeryville,  2003 [8]	 Beebe  N.L., & Clark  J.G.  A Hierarchical, Objectives-Based Framework for the Digital  Investigations Process. Digit. Invest.  2005,  2 (2) [9]	 Cohen  Frederick B. “Fundamentals of Digital Forensic Evidence, Chapter in Handbook of  Information and Communication Security”,  2010, accessed at all.net on 04.01
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 7 (char 6)
# JSON après réparation (premiers 600 chars) : [14]	 Scientific Working Group on Digital Evidence (SWGDE). Position on the National Research  Council Report to Congress  —  Strengthening Forensic Science in the United States: A Path  Forward,  2009 [15]	 Garfinkel  S., Farrella  P., Roussev  V., Dinolt  G.  Bringing science to digital forensics with  standardized forensic corpora. Digit. Invest.  2009,  6 pp. S2–S11 [16]	 Pollitt  M. Applying Traditional Forensic Taxonomy to Digital Forensics”, Advances in Digital  Forensics IV, IFIP TC11.9 Conference Proceedings,  2009 [17]	 Séamus  Ó., & Ciardhuáin  An Extended Model of Cybercrime Invest
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 7 (char 6)
# JSON après réparation (premiers 600 chars) : [20]	 “ACPO  Good  Practice  Guide  for  Computer-Based  Evidence”,  http://www.7safe. com/electronic_evidence/ACPO_guidelines_computer_evidence_v4_web.pdf,  2008 [21]	 Rowlingson  Robert A Ten Step Process for Forensic Readiness”, International Journal of Digital  Evidence, Volume 2, Issue 3,  2004 [22]	 Committee on Identifying the Needs of the Forensic Sciences Community, National  Research Council. Strengthening Forensic Science in the United States: A Path Forward.  National Academies Press,  2009 [23]	 ISO 9000, Quality management systems — Fundamentals and vocabulary [24]	 ISO 15489-1,
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 7 (char 6)
# JSON après réparation (premiers 600 chars) : [28]	 ISO/IEC  27004:2009, Information technology  — Security techniques  — Information security  management — Measurement [29]	 ISO/IEC  27035 (all parts), Information technology  — Security  — Information security incident  management1) [30]	 ISO/IEC 27037:2012, Information technology — Security techniques — Guidelines for identification,  collection, acquisition and preservation of digital evidence [31]	 ISO/IEC 27038, Information technology — Security techniques — Specification for digital redaction [32]	 ISO/IEC 27040, Information technology — Security techniques —Storage Security [33]	 I
# Récupéré 1 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 7 (char 6)
# JSON après réparation (premiers 600 chars) : [38]	 ILAC-G19, Guidelines for forensic science laboratories [40]	 Valjarevic  A., & Venter  H.S. Harmonised Digital Forensic Investigation Process Model”,  International workshop on Digital Forensics in the Cloud (IWDFC), South Africa,  2012 1)	  Under preparation. 2)	  To be published. 3)	  To be published. 4)	  Under preparation. 5)	  Under preparation. ﻿ © ISO/IEC 2015 – All rights reserve 29   ﻿ ISO/IEC 27043:2015(E) [41]	 Valjarevic  A., & Venter  H.S. Analyses of the State-of-the-art Digital Forensic Investigation  Process Models”, The Southern Africa Telecommunication Networks and Ap
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Extra data: line 1 column 416 (char 415)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les deux parties de l'NIST Interagency/Internal Report ?", "answer": "\"Part A\", couvre la planification, la conception et spécification des tests"}, {"question": "Quel organisme indépendant a réalisé les tests ?", "answer": "VDG, Inc."}, {"question": "Qu’est-ce que le Commerce propose ?", "answer": "Une mesure de confiance dans les logiciels utilisés lors des enquêtes informatiques"}],"
#
#
#
# Récupéré 2 paires via regex fallback
# Erreur JSON finale : Invalid \escape: line 1 column 564 (char 563)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les erreurs rencontrées lors des tests ?", "answer": "PartabFailures,DiskchgFailures,SeccopyFailures ,PartcmpFailures,SechashFailures,AdjcmpFailures,CorruptFailures"}, {"question": "Quels types de défaillances ont été observées dans la section 'Failed Tests' ?", "answer": "Divers échecs liés aux opérations de manipulation disque (par exemple: partb), hash comparatifs et changements de fichier."}, {"question": "Lequel de ces outils a échoué spécifiquement au test ? ", "answer": "diskchg"} ,"{\"question\":\"Quelle erreur concerne l\'outil `partcmp`?\",\"answer\": \"Pa
# Récupéré 3 paires via regex fallback
# Aucune paire valide après filtre
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 303 (char 302)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels tests ont échoué concernant `Partab`?", "answer":" Test cases: Ptb-13."}, {"question": "Quelle taille maximale de partition FAT32 peut gérer `Partab` ?", "answer": "8GB"}, {"question": "`Diskchg`, quelle fonctionnalité n'a pas réussi son test ?" , "answer": "feature "} ,"question": "Qu'est-ce que la fonction `diskchg` devait faire selon l'énoncé du test ?","answer": "set a sector s to the contents that diskwipe would use...using the specified fill value"}, {"question": "Dans cette spécification de test, quel était le contenu attendu dans le secteur 's' ? ","answer": "the h
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 274 (char 273)
# JSON après réparation (premiers 600 chars) : [{"question":"Quelles sont les erreurs signalées lors des tests `Dch-09` et `Scy-02` ?","answer": "\"Seccopy reports 'Copy length (4) exceeds (12594960) Source disk size (12594956)'\" , \"Seccopy reports 'Copy length (3) exceeds (3335472) Destination disk size (3335469)'"}"}, {"question":"Selon l'auteur, quel problème affecte probablement la fonctionalité de seccopy dans ces cas? ","answer": "An incorrect comparison between start_address + count and last_sector."}, {"question":"Lequel des outils mentionnés semble avoir des problèmes avec les partitions FAT32 supérieures à 8 Go?" ,"answer": "Pa
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 656 (char 655)
# JSON après réparation (premiers 600 chars) : [{"question":"Quel type d'erreur se produit lorsque `sechash` traite un groupe de secteurs contenant uniquement un secteur ?","answer":"Floating point error: Divide by zero"}, {"question":"Selon l'auteur des tests, pourquoi `sechash` rencontre-t-il cette erreur ?","answer":"Il calcule incorrectement le nombre total de secteurs à traiter."}, {"question":"Dans quel test cas la méthode de calcul du nombre total de secteurs semble-elle défectueuse ?" , "answer": "Shs-03"}, {"question":"Qu'est-ce que `sechash` suppose faire lorsqu'un seul secteur fait partie du groupe spécifié ?", "answer": "Calcul
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 846 (char 845)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels outils sont utilisés dans la section ?", "answer": "Seccopy and fs-tst"}, {"question": "Que peut afficher l'outil 'partcmp'?", "answer": "'Partcmp' displays the partition table."}, {"question": "Quelle information précise trouve-t-on dans la table des partitions ?", "answer": "Partition start address in LBA or CHS format"}, {"question": "Pourquoi on ne peut pas utiliser directement l'adresse CHS trouvée dans la table des partitions pour copier les secteurs d'une partition ? ", "answer":"Because the BIOS uses a different disk geometry to compensate for its limitations."}, {
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid \escape: line 1 column 393 (char 392)
# ...
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 288 (char 287)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les versions exactes des outils utilisés dans la test case NR-05?", "answer": "FTK 7.0.0.163, Registry Viewer 2 .0.0.7"}, {"question": "Quel type de problème rencontré lors du test NR-01-1 ?", "answer": "'un outil signalé incorrectement une valeur QWORD'}, {"question": "Que signifie 'a QWORD value stores \'8\'" ?"," answer":"'}une valeur QWORD stocke \'8'\""}, {"question": "Comment était interprétée cette valeur QWORD selon l'outil? ","answer":"'le outil a interprété les données comme \'34359738368'." }, {"question": "Quels types de résultats étaient attendus (AS EX
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 5 column 1 (char 364)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les limitations signalées concernant la prise en charge des erreurs dans l'outil ?", "answer": "\"Le outil n'appuie pas ce genre de corruption.\""}, {"question": "Comment l'outil traite-t-il les objets répertoriés comme corrompus ?", "answer": "\"L'outil traitait probablement ignoré corruptée objets registre sans erreur...\" \""}]
#
#
#
# ```json
# {
#     "question":"Quel type de clé était identifié suite aux modifications apportées au 'root cell offset' ?" ,
#    "answer":"\"le 1er sous-clé de la clé racine originale\""}
#  {
#      "question": "Quels types de données étaient pr
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 454 (char 453)
# JSON après réparation (premiers 600 chars) : [{"question": "Quel outil était utilisé dans ces tests ?", "answer":" FTK"}, {"question": "Quelle version précise du logiciel FTK était utilisée ?","answer":"7.0.0.163"}, {"question": "Qu'est-ce que l'outil considérait comme facteur clé lors du parseage des clés?", "answer":" 'Cell size'" }, {"question": "Dans quel cas précis n'a-t-il pas identifié toutes les clés ?" , "answer":" Lorsque la valeur 'Number of subkeys' avait été modifiée"} ,"question": "Quelles étaient les versions exactes utilisées pour chaque module testé? ","answer":"Registry Viewer 2.0.0.7"}]
#
#
#
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 1084 (char 1083)
# JSON après réparation (premiers 600 chars) : [{"question": "Quels sont les problèmes rencontrés lors des tests MR-06-3 ?", "answer": "Le outil a identifié un mauvais flux de données dû au 'offset de données' nul dans une cellule valeur (vk)."}, {"question": "Quel problème était signalé concernant l'identification des grands flux de données ?", "answer": "'L'outil n'a pas identifié un grand flux de données en raison du 'taille de données' nulle dans une cellule valeur (vk)'."}, {"question": "Quelle version de FTK a été utilisée pour ces tests ?", "answer": "FTK 7.0.0.163"}, {"question": "Qu'est-ce que l'on observe dans la description du t
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 478 (char 477)
# JSON après réparation (premiers 600 chars) : [{"question": "Quel type de fichier était analysé ?", "answer": "hive"}, {"question": "Lequel des problèmes rencontrés concernait la taille?", "answer": "'data size' item beyond a cell’s boundary"}, {"question": "Comment l'outil s'est-il comporté face aux boucles infinies ?" , "answer":"terminated without any notification"}, {"question": "Quelles valeurs ont été identifiées comme invalides ?","answer": "integer VALUE 0x04 (DWORD-LE),binary VALUE 0x03 (BINARY),string VALUE 	(SZ)"}]
#
#
#
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Extra data: line 1 column 794 (char 793)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels rapports peut créer l'outil ?","answer":"Registry Summary Reports"},{"question": "Quelles informations système sont incluses dans la génération des données ?", "answer":"Applications (Prefetch, UserAssist, Installed), Browsers (Downloads, URLs), Network Information (Network Connections, Wireless Profiles), Owner Information, Recent Files, SAM Users and USB Devices."}, {"question": "Quel type de fichier utilise File Signature Analysis?", "answer":"Non spécifié"}, {"question": "Lequel de ces éléments n'est pas inclus dans les systèmes informatiques analysés? ","answer":"Volat
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Case-Directory]\registry_viewer\AutoRSR\’.   Built-in Parsers in Registry Viewer  ◦ The ‘Key Properties’ and ‘Value Properties’ viewers of Registry Viewer
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
# Tu DOIS générer exactement 6 paires complètes. Chaque paire doit être un objet JSON complet avec "question" et "answer" valides. Ne laisse JAMAIS un objet ouvert ou une virgule en trop. Si le chunk est court, génère moins mais toujours complet.
#
#
# {"question": "Quels sont
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 329 (char 328)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles versions des logiciels sont mentionnées dans le texte ?", "answer": " FTK 7.0.0.163, Registry Viewer 2"}, {"question": "Quel type d'artefact est analysé dans l'exemple 'FA-01'", "answer": "SAM Users"}, {"question": "Quels rapports existent concernant les utilisateurs SAM ?", "answer": "'SAM – Users'}, {"question": "Que peut analyser la section \"SOFTWARE\" ?" , "answer":"Installed Software,"}, {"question": "Dans quel logiciel trouve-t-on l'information contenue dans le tableau ? ", "answer": "The text does not specify."}]
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Expecting property name enclosed in double quotes: line 1 column 736 (char 735)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels champs sont rapportés par l'analyseur d'entrée Utilisateur dans la ruche SAM ?","answer":"RID unique identifier, Nom d'utilisateur, Description, Nombre de connexions, Dernière connexion, Dernier changement de mot de passe, Heure d'expiration, Contre nombre de tentatives non valides, Dernière tentative de connexion échouée, Compte désactivé, Mot de passe requis, Code pays, Heures autorisées, Hashes NT et LM."}, {"question": "Quel champ spécifique n'est pas mentionné comme étant extrait des données 'RecentDocs'? ","answer":"Le type de fichier associé au raccourci"}, {"questio
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Windows: 10RS1]  - The FTK reported user names only. It did not identify NT Hash values.                                                                                                                                                                                                                                                ◦ Note that the FTK reported user names and NT Hash values only. That is, it did not
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie fortement les questions.
# Assure-toi de générer EXACTEMENT 6 à 8 paires complètes. Termine toujours par ] et rien après.
# Tu DOIS génére
# Récupéré 6 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Windows: ALL9]   Application  ◦ Partial application related data was reported. [Windows: 10, 10RS1]  - In the FTK and RSR, 32-bit (x86) application related data in 64-bit Windows  systems was not reported. That is, they ignored Wow6432Node key on 64-bit  Windows systems.  ◦ All three ways (FTK, RSR and RV) did not support to extract Windows Store app10  related data.   Auto Run  ◦ Partial auto run related data was reported. [Windows: 10, 10RS1]  - In the RSR, 32-bit (x86) application related data in 64-bit Windows systems was  not reported. That is, the tool ignored Wow6432Node key on 64-bi
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Windows: 10, 10RS1]  - The RSR did not identify dialog usage history from well-known keys, such as  LastVisitedPidMRU and OpenSavePidMRU as listed in Table 4.   External Device  ◦ All USB storage devices were reported as expected, but the following findings need  to be taken into consideration. [Windows: ALL]  - The FTK identified USB storage devices and associated timestamps from Enum,  and DeviceClasses keys of the SYSTEM hive. That is, the tool did not identify  those data from other well-known keys, such as DeviceContainers, EMDMgmt
#
# Génère UNIQUEMENT le JSON valide maintenant. Varie for
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Windows: 8, 8.1, 10, 10RS1]   Network Drive  ◦ Network drive related data was not reported. [Windows: 10, 10RS1]  - The FTK and RSR did not report network drive history.  ◦ Network drive related data was reported as expected, but the following findings need  to be taken into consideration. [Windows: Vista, 7, 8, 8.1]  - The FTK and RSR identified network drives and associated timestamps from Map Network Drive MRU and MountPoints2 keys of the NTUSER hive. That is, the tool did not identify those data from another well-known key, Network as listed in Table 4.         OS Information  ◦ OS Info
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Windows: Vista, 7, 8, 8.1]  - The FTK identified recent file history on famous user applications such as Adobe  Reader and MS Office (Excel, PowerPoint, Word). That is, the tool did not report  those data from another well-known key, RecentDocs as listed in Table 4.  ◦ Opened file and directory related data was not reported. [Windows: 10, 10RS1]  - The FTK and RSR did not report opened file and directory related data.   Run Command  ◦ Run command related data was not reported. [Windows: 10, 10RS1]  - The RSR failed to generate an RSR report related to run command history.  April 2019  21  FT
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Network]\10.11.11.127\\\10.11.11.127\network_dir\ND+Samples\                          ShellBag ◦ Partial ShellBag related data was reported. [Windows: ALL] - The FTK reported ShellBag related data in USRCLASS hives, but those data in NTUSER hives were not reported. [Windows: 10, 10RS1] - The FTK did not report MRU timestamps11. That is, the tool only reported MAC (Modified/Accessed/Created) timestamps stored within each ShellBag entry. - The FTK incorrectly reported directory paths relating to network drives. 11 The MRU (Most Recently Used) timestamp can be identified from each key cell. Ana
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Expecting value: line 1 column 2 (char 1)
# JSON après réparation (premiers 600 chars) : [Windows 7]:          on ‘Name’ and  ‘Full Path’ fields    were reported.      ◦ The tool reported invalid    characters on ‘Name’ and ‘Full Path’ fields.         UserAssist  ◦ UserAssist related data was not reported. [Windows: 10, 10RS1]  - The FTK did not report UserAssist entries.  ◦ Partial UserAssist related data was reported. [Windows: 7, 8, 8.1]  - The FTK only reported values having a ‘run count’ greater than 1. That is, the  tool ignored other UserAssist values, which do not store ‘run count’ information  as shown in the below example.  Description  Related screenshots
# Récupéré 5 paires via regex fallback
# Erreur JSON finale : Invalid control character at: line 1 column 595 (char 594)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les fonctionnalités manquantes dans l'outil utilisé lors des tests?", "answer": "L'outil n'a pas pu extraire de données relatives aux cartes réseau comme l'adresse IP assignée, la passerelle et les adresses DNS."}, {"question": "Quels types de recherches ont été effectués ?", "answer":"Remote Desktop ,Search,Service and Driver,Shared Directory"}, {"question": "Quelle version exacte de FTK a été utilisée ?", "answer": "FTK 7.0.0.163"}, {"question": "Dans quel contexte précis était-ce que cette analyse avait lieu ? ", "answer": "Tests réalisés en avril 2019"} ,"
#
#
#
# ]
# Récupéré 4 paires via regex fallback
# Erreur JSON finale : Invalid \escape: line 1 column 1010 (char 1009)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels sont les noms des différents éléments analysés dans cet échantillon ?", "answer":["App Compatibility (Amcache), App Compatibility (Shimcache), Auto Run , Dialog Usage, External Device, Network Connection, Network Drive, OS Information, Recently Opened Files & Directories, Remote Desktop, Run Command, Search, Service and Driver, Shared Directory, ShellBag, Timezone"]}, {"question": "¿Qué tipo de información se almacena en el registro 'Application Compatibility'?", "answer":["Informations about application compatibility."] }, {"question": "Quelles informations concernant l'ex
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Extra data: line 1 column 140 (char 139)
# JSON après réparation (premiers 600 chars) : [{"question":"Quelles sont les versions spécifiques des logiciels utilisés dans l'enquête ?","answer":" FTK 7.0.0.163, Registry Viewer 2"}],"
#
#
#
# Récupéré 1 paires via regex fallback
# Aucun [ trouvé → pas de JSON
# Échec parsing sur un chunk → ignoré
# Aucun [ trouvé → pas de JSON
# Échec parsing sur un chunk → ignoré
# Aucun [ trouvé → pas de JSON
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Expecting ',' delimiter: line 1 column 559 (char 558)
# JSON après réparation (premiers 600 chars) : [{"question": "Quelles sont les trois principales considérations qui influencent les méthodes utilisées dans la science médico-légale ?", "answer": "Le type de support ou dispositif, la situation et les délais et coûts."}, {"question": "Quel objectif poursuit le processus de préservation des preuves ?", "answer": "La protection de l'intégrité des preuves à chaque étape"}, {"question": "En plus de protéger contre la dégradation involontaire, quel autre risque vise également la conservation des preuves ?" , "answer": "Les modifications intentionnelles ("tampering")."}]
# Récupéré 2 paires via regex fallback
# Aucun [ trouvé → pas de JSON
# Échec parsing sur un chunk → ignoré
# Erreur JSON finale : Extra data: line 9 column 2 (char 927)
# JSON après réparation (premiers 600 chars) : [ {"question":"Comment s'assurer que toutes les données potentiellement pertinentes ont été collectées?", "answer":"Etiquetez, déconnectez et mettez en sécurité les câbles et les ports d’entrée / sortie."},
#     { "question":"Que faire lorsqu'un ordinateur portable est utilisé dans une enquête ?" , "answer":"Enlever les batteries"},
#      { "question":"Quels types de procédures doivent être prisent lors de la collecte des informations d'un dispositif informatique allumé ?" ,"answer": "Considérez l'acquisition logique lorsque vous soupçonnez la présence de disques ou de partitions cryptées. La co
# Récupéré 3 paires via regex fallback
# Erreur JSON finale : Extra data: line 4 column 2 (char 353)
# JSON après réparation (premiers 600 chars) : [{"question":"Quels types de dispositifs sont considérés comme des \"dispositifs connectés en réseau\" ?","answer":"Des appareils définis dans le contexte 'Scenari di applicazione – dispositivi in rete'."}, {"question":"Quelle est la première étape recommandée lors de l'acquisition physique d'un ordinateur? ","answer":"Retirer les disques durs."}]
#
#
#  ```
# Récupéré 1 paires via regex fallback
# Aucun [ trouvé → pas de JSON
# Échec parsing sur un chunk → ignoré
# Total Q/R générées et parsées : 4215

# %%
import json
import random
from collections import Counter
import re
from pathlib import Path
from IPython.display import FileLink
import pandas as pd
import numpy as np
#Questions reponses Path
json_path = Path("/kaggle/input/qa-clean/questions_reponses_300.json")

if not json_path.exists():
    raise FileNotFoundError("Le fichier JSON n'est pas trouvé. Vérifie le chemin.")

with open(json_path, 'r', encoding='utf-8') as f:
    raw_qa = json.load(f)

print(f"Total paires brutes chargées : {len(raw_qa)}")

def is_valid_pair(item):
    if not isinstance(item, dict):
        return False
    q = item.get("question", "").strip()
    a = item.get("answer", "").strip()
    return bool(q and a and len(q) > 10 and len(a) > 2)

seen = {}
clean_qa = []

for item in raw_qa:
    if not is_valid_pair(item):
        continue
    q_norm = re.sub(r'\s+', ' ', item["question"].lower().strip())
    if q_norm not in seen:
        seen[q_norm] = True
        clean_qa.append({
            "question": item["question"].strip(),
            "answer": item["answer"].strip()
        })

print(f"Après nettoyage et dédoublonnage : {len(clean_qa)} paires uniques valides")
# Clean & Fully ready dataset Q/A
clean_path = "/kaggle/working/forensic_qa_clean.json"
with open(clean_path, "w", encoding="utf-8") as f:
    json.dump(clean_qa, f, ensure_ascii=False, indent=2)

FileLink('forensic_qa_clean.json')

# 300 Q/A Samples as dataset
if len(clean_qa) >= 300:
    sampled_qa = random.sample(clean_qa, 300)
else:
    sampled_qa = clean_qa
    print(f"Moins de 300 paires uniques → on prend tout ({len(sampled_qa)})")

questions = [item["question"] for item in sampled_qa]
ground_truths = [item["answer"] for item in sampled_qa]

print(f"Prêt à tester {len(questions)} questions.")

#Check stats
q_counts = Counter(questions)
dupl = {q: c for q, c in q_counts.items() if c > 1}
if dupl:
    print(f"\nIl reste {len(dupl)} questions dupliquées (max {max(dupl.values())} fois)")
else:
    print("Aucun doublon restant après nettoyage.")
# Out:
# Total paires brutes chargées : 300
# Après nettoyage et dédoublonnage : 0 paires uniques valides
# Moins de 300 paires uniques → on prend tout (0)
# Prêt à tester 0 questions.
# Aucun doublon restant après nettoyage.

# %%
import json
import random
from pathlib import Path

json_path = Path("/kaggle/input/qa-clean/questions_reponses_300.json")

if not json_path.exists():
    print("Fichier non trouvé ! Vérifie le chemin.")
else:
    with open(json_path, 'r', encoding='utf-8') as f:
        all_qa = json.load(f)
    
    print(f"Total paires chargées : {len(all_qa)}")
    
    if all_qa and isinstance(all_qa[0], dict) and "question" in all_qa[0] and "answer" in all_qa[0]:
        print("Exemple première paire :", all_qa[0])
    else:
        print("Structure inattendue ! Vérifie le format.")
    
    if len(all_qa) >= 300:
        sampled_qa = random.sample(all_qa, 300)
    else:
        sampled_qa = all_qa
        print(f"Moins de 300 paires → on prend tout ({len(sampled_qa)})")
    
    questions = [item["question"] for item in sampled_qa]
    ground_truths = [item["reponse"] for item in sampled_qa]
    
    print(f"Prêt à tester {len(questions)} questions.")
# Out:
# Total paires chargées : 300
# Structure inattendue ! Vérifie le format.
# Prêt à tester 300 questions.

# %%
from unsloth import FastLanguageModel
import torch
from tqdm.auto import tqdm

def load_model(model_name):
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name,
        max_seq_length=2048,
        dtype=None,
        load_in_4bit=True,
    )
    FastLanguageModel.for_inference(model)
    return model, tokenizer

def generate_answer(model, tokenizer, question):
    prompt = f"""Tu es un expert en digital forensics. Réponds **UNIQUEMENT** par la réponse courte exacte. Pas de phrase complète, pas d'explication, pas d'introduction, pas de conclusion. Juste le contenu factuel attendu.

Question : {question}

Réponse :"""
    
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=60,
            temperature=0.0,
            do_sample=False,
            repetition_penalty=1.1,
            eos_token_id=tokenizer.eos_token_id
        )
    
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    if "Réponse :" in response:
        return response.split("Réponse :")[-1].strip()
    else:
        return response.strip().replace(prompt, "").strip()

models_to_test = {
    "Gemma-2-9B": "unsloth/gemma-2-9b-it-bnb-4bit",
    "Qwen2.5-7B": "unsloth/Qwen2.5-7B-Instruct-bnb-4bit",
    "Llama-3.2-3B": "unsloth/Llama-3.2-3B-Instruct-bnb-4bit"
}

results = {}

for name, model_path in models_to_test.items():
    print(f"\n=== Test de {name} ===")
    
    model, tokenizer = load_model(model_path)
    
    predictions = []
    for q in tqdm(questions, desc=f"Génération {name}"):
        pred = generate_answer(model, tokenizer, q)
        predictions.append(pred)
    
    results[name] = predictions
    
    del model, tokenizer
    torch.cuda.empty_cache()
    
    print(f"{name} terminé ({len(predictions)} réponses générées)")
# Out:
# /tmp/ipykernel_56/2084996483.py:1: UserWarning: WARNING: Unsloth should be imported before [transformers] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
#
# === Test de Gemma-2-9B ===
# ==((====))==  Unsloth 2026.1.4: Fast Gemma2 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/6.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Génération Gemma-2-9B:   0%|          | 0/300 [00:00<?, ?it/s]
# Gemma-2-9B terminé (300 réponses générées)
#
# === Test de Qwen2.5-7B ===
# ==((====))==  Unsloth 2026.1.4: Fast Qwen2 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.55G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Génération Qwen2.5-7B:   0%|          | 0/300 [00:00<?, ?it/s]
# Qwen2.5-7B terminé (300 réponses générées)
#
# === Test de Llama-3.2-3B ===
# ==((====))==  Unsloth 2026.1.4: Fast Llama patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Génération Llama-3.2-3B:   0%|          | 0/300 [00:00<?, ?it/s]
# Llama-3.2-3B terminé (300 réponses générées)

# %%
# !pip install rouge-score bert-score nltk
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.57.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.5)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (26.0rc2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2026.1.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert-score) (1.2.1rc0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.3)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: bert-score
# Successfully installed bert-score-0.3.13

# %%
def clean_response(text):
    text = text.strip()
    prefixes = ["La réponse est", "Il s'agit de", "C'est", "Réponse :", "L'outil est", "L'action est"]
    for p in prefixes:
        text = text.replace(p, "", 1).strip()
    text = text.split('\n')[0].split('.')[0].strip()
    text = re.sub(r'`|\*|_', '', text).strip()
    return text


for model_name in results:
    results[model_name] = [clean_response(p) for p in results[model_name]]

# %%
import re
import string
from collections import Counter
from rouge_score import rouge_scorer
from bert_score import score
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def normalize_answer(s):
    s = s.lower()
    s = re.sub(r'\b(a|an|the)\b', ' ', s)
    s = re.sub(r'[^a-z0-9\s]', '', s)
    s = ' '.join(s.split())
    return s.strip()

def exact_match(pred, gt):
    return normalize_answer(pred) == normalize_answer(gt)

def f1_token(pred, gt):
    p = normalize_answer(pred).split()
    g = normalize_answer(gt).split()
    common = Counter(p) & Counter(g)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    precision = num_same / len(p)
    recall = num_same / len(g)
    return 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

# Calcul scores
scores = {}

for model_name, preds in results.items():
    em = []
    f1 = []
    rougeL = []
    
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    
    for p, gt in zip(preds, ground_truths):
        em.append(1 if exact_match(p, gt) else 0)
        f1.append(f1_token(p, gt))
        rougeL.append(scorer.score(gt, p)['rougeL'].fmeasure)
    
    _, _, bert_f1 = score(preds, ground_truths, lang="en", rescale_with_baseline=True)
    
    scores[model_name] = {
        "Exact Match": np.mean(em),
        "F1 Token": np.mean(f1),
        "ROUGE-L": np.mean(rougeL),
        "BERTScore F1": bert_f1.mean().item()
    }
print("Exemples de prédictions vs ground truth (10 premiers) :\n")
for i in range(min(10, len(questions))):
    print(f"Question : {questions[i]}")
    print(f"Ground truth : {ground_truths[i]}")
    print(f"Gemma-2-9B   : {results['Gemma-2-9B'][i]}")
    print(f"Qwen2.5-7B   : {results['Qwen2.5-7B'][i]}")
    print(f"Llama-3.2-3B : {results['Llama-3.2-3B'][i]}")
    print("-" * 80)

# Metrics details for each model
import pandas as pd
df = pd.DataFrame(scores).T
df = df.round(4)
print("\n=== Résultats comparatifs ===")
print(df)


best_model = df["BERTScore F1"].idxmax()
print(f"\nMeilleur modèle selon BERTScore : {best_model} ({df.loc[best_model, 'BERTScore F1']:.4f})")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Exemples de prédictions vs ground truth (10 premiers) :
#
# Question : (freebsddd-setup-procs.pdf) Quel intitulé est donné exactement dans «freebsddd-setup-procs.pdf» ? Repère: "1. /bin/csh -f"
# Ground truth : 1. #!/bin/csh -f
# Gemma-2-9B   : FreeBSD setup procedures
# Qwen2.5-7B   : mem
# Llama-3.2-3B : csh
# --------------------------------------------------------------------------------
# Question : (The_new_ISO_IEC_27037_acquisition_and_pr.pdf) Quel intitulé est donné exactement dans «The_new_ISO_IEC_27037_acquisition_and_pr.pdf» ? Repère: "oltre ad essere in grado di assolvere i"
# Ground truth : oltre ad essere in grado di assolvere i compiti del
# Gemma-2-9B   : Acquisition and Preservation of Digital Evidence
# Qwen2.5-7B   : Acquisition and Preservation of Evidence for Digital Forensic Investigations
# Llama-3.2-3B : Acquisition and preservation of digital evidence
# --------------------------------------------------------------------------------
# Question : (SWGDE_Best_Practices_for_Digital_Forensic_Video_Analysis.pdf) Quelle extension de fichier est mentionnée dans «SWGDE_Best_Practices_for_Digital_Forensic_Video_Analysis.pdf» (.pdf) ? Repère: "-- Document: SWGDE_Best_Practices_for_Digital_Forensic_Video"
# Ground truth : -- Document: SWGDE_Best_Practices_for_Digital_Forensic_Video_Analysis.pdf --
# Gemma-2-9B   :
# Qwen2.5-7B   : document de pratique recommand
# Llama-3.2-3B :
# --------------------------------------------------------------------------------
# Question : (Guidelines_to_Digital_Forensics_First_Responders_V7.pdf) Quel libellé est écrit mot pour mot dans «Guidelines_to_Digital_Forensics_First_Responders_V7.pdf» ? Repère: "standards in their jurisdictions."
# Ground truth : standards in their jurisdictions.
# Gemma-2-9B   : standards in their jurisdictions
# Qwen2.5-7B   : 采集和固定电子证据。
# Llama-3.2-3B : Les normes locales dans leurs juridictions
# --------------------------------------------------------------------------------
# Question : (SWGDE_Best_Practices_for_Digital_Forensic_Video_Analysis.pdf) Quel énoncé exact figure dans «SWGDE_Best_Practices_for_Digital_Forensic_Video_Analysis.pdf» ? Repère: "c Documentation may be accomplished through handwritten or"
# Ground truth : c) Documentation may be accomplished through handwritten or electronically generated
# Gemma-2-9B   : typed notes
# Qwen2.5-7B   : c Documentation may be accomplished through handwritten or
# Llama-3.2-3B : "Documentation may be accomplished through handwritten or electronic means
# --------------------------------------------------------------------------------
# Question : (Guidelines_to_Digital_Forensics_First_Responders_V7.pdf) Quelle phrase est présente telle quelle dans «Guidelines_to_Digital_Forensics_First_Responders_V7.pdf» ? Repère: "Do not turn on the equipment again."
# Ground truth : Do not turn on the equipment again.
# Gemma-2-9B   : Do not turn on the equipment again
# Qwen2.5-7B   :
# Llama-3.2-3B : Do not turn on the equipment again
# --------------------------------------------------------------------------------
# Question : (forensic_test_report.pdf) Quel énoncé exact figure dans «forensic_test_report.pdf» ? Repère: "/noask /new_log"
# Ground truth : /noask /new_log
# Gemma-2-9B   : Le rapport indique que l'utilisateur a tenté d'accéder à des fichiers protégés par mot de passe
# Qwen2.5-7B   : 150 gigabytes
# Llama-3.2-3B : "No ask new log"
# --------------------------------------------------------------------------------
# Question : (Cybercriminalit.pdf) Quel intitulé est donné exactement dans «Cybercriminalit.pdf» ? Repère: "de nature comparable conform ment la l gislation"
# Ground truth : de nature comparable conformément à la législation de cette Partie.
# Gemma-2-9B   : conformément
# Qwen2.5-7B   : Cybercriminalité de nature comparable conformément à la législation
# Llama-3.2-3B : La criminalité informatique
# --------------------------------------------------------------------------------
# Question : (Cybercriminalit.pdf) Quel énoncé exact figure dans «Cybercriminalit.pdf» ? Repère: "a. la production de pornographie enfantine en vue"
# Ground truth : a. la production de pornographie enfantine en vue de sa diffusion par le biais d’un système
# Gemma-2-9B   :
# Qwen2.5-7B   : a
# Llama-3.2-3B : a
# --------------------------------------------------------------------------------
# Question : (X-Ways Forensics 16 2 SR-5 TestReport_0.pdf) Quelle formulation exacte apparaît dans «X-Ways Forensics 16 2 SR-5 TestReport_0.pdf» ? Repère: "the selected digital source the tool notifies the"
# Ground truth : the selected digital source, the tool notifies the
# Gemma-2-9B   : the selected digital source the tool notifies the
# Qwen2.5-7B   : the selected digital source the tool notifies the user if no media is inserted into the drive or if the media is write protected To be verified
# Llama-3.2-3B : "the selected digital source the tool notifies the user about"
# --------------------------------------------------------------------------------
#
# === Résultats comparatifs ===
#               Exact Match  F1 Token  ROUGE-L  BERTScore F1
# Gemma-2-9B         0.0933    0.3598   0.3856        0.0059
# Qwen2.5-7B         0.0433    0.2252   0.2431       -0.1662
# Llama-3.2-3B       0.0900    0.3555   0.3812       -0.1462
#
# Meilleur modèle selon BERTScore : Gemma-2-9B (0.0059)
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.

# %%
with open("/kaggle/working/predictions.json", "w") as f:
    json.dump(results, f, ensure_ascii=False, indent=2)

# %%
# !pip install sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.0rc2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.1rc0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2026.1.4)
# Downloading faiss_cpu-1.13.2-cp310-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 41.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.2

# %%
import fitz
import os

# Knowledge base Path
pdf_folder = "/kaggle/input/forensic"
chunks = []

for pdf_file in os.listdir(pdf_folder):
    if pdf_file.lower().endswith(".pdf"):
        path = os.path.join(pdf_folder, pdf_file)
        doc = fitz.open(path)
        text = ""
        for page in doc:
            text += page.get_text("text") + "\n\n"
        doc.close()

        current = ""
        for line in text.split("\n"):
            if len(current) + len(line) > 1200:
                chunks.append(current.strip())
                current = line
            else:
                current += " " + line
        if current:
            chunks.append(current.strip())

print(f"Base de connaissance prête : {len(chunks)} chunks")
# Out:
# Base de connaissance prête : 986 chunks

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

embedder = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')

print("Embedding des chunks...")
chunk_embeddings = embedder.encode(chunks, show_progress_bar=True, batch_size=32)
chunk_embeddings = np.array(chunk_embeddings).astype('float32')

dimension = chunk_embeddings.shape[1]
index = faiss.IndexFlatIP(dimension)
faiss.normalize_L2(chunk_embeddings)
index.add(chunk_embeddings)

print(f"Index FAISS créé avec {index.ntotal} vecteurs")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding des chunks...
# Batches:   0%|          | 0/31 [00:00<?, ?it/s]
# Index FAISS créé avec 986 vecteurs

# %%
def rag_generate(question, model, tokenizer, top_k=3):
    q_emb = embedder.encode([question])[0].astype('float32')
    faiss.normalize_L2(q_emb.reshape(1, -1))
    

    distances, indices = index.search(q_emb.reshape(1, -1), top_k)
    
    retrieved = []
    for idx in indices[0]:
        if idx != -1:
            retrieved.append(chunks[idx])
    
    context = "\n\n".join(retrieved)
    
    # Prompt RAG
    prompt = f"""Tu es un expert en digital forensics. Utilise UNIQUEMENT les informations suivantes pour répondre.

Contexte extrait :
{context}

Question : {question}

Réponds UNIQUEMENT par la réponse courte et exacte, sans explication :
Réponse :"""
    
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=60,
            temperature=0.0,
            do_sample=False,
            pad_token_id=tokenizer.eos_token_id
        )
    
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    if "Réponse :" in response:
        return response.split("Réponse :")[-1].strip()
    return response.strip()

# %%
from unsloth import FastLanguageModel

model_name = "unsloth/gemma-2-9b-it-bnb-4bit"
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name,
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
)
FastLanguageModel.for_inference(model)

rag_predictions = []
for q in tqdm(questions, desc="Génération RAG"):
    pred = rag_generate(q, model, tokenizer, top_k=3)
    rag_predictions.append(pred)

del model, tokenizer
torch.cuda.empty_cache()
# Out:
# ==((====))==  Unsloth 2026.1.4: Fast Gemma2 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Génération RAG:   0%|          | 0/300 [00:00<?, ?it/s]

# %%
rag_em = [exact_match(p, gt) for p, gt in zip(rag_predictions, ground_truths)]
rag_f1 = [f1_token(p, gt) for p, gt in zip(rag_predictions, ground_truths)]
rag_rouge = [scorer.score(gt, p)['rougeL'].fmeasure for p, gt in zip(rag_predictions, ground_truths)]
_, _, rag_bert = score(rag_predictions, ground_truths, lang="fr" if "fr" in questions[0].lower() else "en")

rag_scores = {
    "Exact Match": np.mean(rag_em),
    "F1 Token": np.mean(rag_f1),
    "ROUGE-L": np.mean(rag_rouge),
    "BERTScore F1": rag_bert.mean().item()
}

print("\nScores SANS RAG (précédents) :")
print(df)

print("\nScores AVEC RAG :")
print(pd.Series(rag_scores).to_frame().T.round(4))

print(f"Gain BERTScore : {rag_scores['BERTScore F1'] - df.loc['Llama-3.2-3B', 'BERTScore F1']:.4f}")
# Out:
# Scores SANS RAG (précédents) :
#               Exact Match  F1 Token  ROUGE-L  BERTScore F1
# Gemma-2-9B         0.0933    0.3598   0.3856        0.0059
# Qwen2.5-7B         0.0433    0.2252   0.2431       -0.1662
# Llama-3.2-3B       0.0900    0.3555   0.3812       -0.1462
#
# Scores AVEC RAG :
#    Exact Match  F1 Token  ROUGE-L  BERTScore F1
# 0       0.1833    0.4432   0.4755        0.7378
# Gain BERTScore : 0.8840
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
# Warning: Empty candidate sentence detected; setting raw BERTscores to 0.
